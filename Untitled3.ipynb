# %% [markdown]
# <a href="https://colab.research.google.com/github/Khavyasaro/Sprints/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 325 (delta 159), reused 156 (delta 156), pack-reused 107
# Receiving objects: 100% (325/325), 2.23 MiB | 17.60 MiB/s, done.
# Resolving deltas: 100% (165/165), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 38.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 70.2 MB/s eta 0:00:00

# %%
# !pip install numpy

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 804876
# drwxr-xr-x 2 root root      4096 Jun  6 12:35 .
# drwxr-xr-x 3 root root      4096 Jun  6 12:34 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt.1
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt.1
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt.1
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt.1

# %%
SRC_IMG_PATH = "/content/yolov9/fish.jpg"

# %%
# !python detect.py --weights {HOME}/weights/yolov9-c.pt --conf 0.1  --source /content/yolov9/fish.jpg --device cpu
# Out:
# detect: weights=['{HOME}/weights/yolov9-c.pt'], source=/content/yolov9/fish.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 724 layers, 51141120 parameters, 0 gradients, 238.7 GFLOPs
# image 1/1 /content/yolov9/fish.jpg: 544x640 1 bird, 4137.8ms
# Speed: 1.5ms pre-process, 4137.8ms inference, 34.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %%
from IPython.display import Image

Image(filename= f"/content/yolov9/runs/detect/exp/fish.jpg", width = 1000)

# %%
SRC_IMG_PATH = "/content/yolov9/banana.jpg"

# %%
# !python detect.py --weights {HOME}/weights/yolov9-c.pt --conf 0.1  --source /content/yolov9/banana.jpg --device cpu
# Out:
# detect: weights=['{HOME}/weights/yolov9-c.pt'], source=/content/yolov9/banana.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 724 layers, 51141120 parameters, 0 gradients, 238.7 GFLOPs
# image 1/1 /content/yolov9/banana.jpg: 384x640 1 banana, 4150.2ms
# Speed: 2.3ms pre-process, 4150.2ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
from IPython.display import Image

Image(filename= f"/content/yolov9/runs/detect/exp2/banana.jpg", width = 1000)

# %%
SRC_IMG_PATH = "/content/yolov9/tiger.jpg"

# %%
# !python detect.py --weights {HOME}/weights/yolov9-c.pt --conf 0.1  --source /content/yolov9/tiger.jpg --device cpu
# Out:
# detect: weights=['{HOME}/weights/yolov9-c.pt'], source=/content/yolov9/tiger.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 724 layers, 51141120 parameters, 0 gradients, 238.7 GFLOPs
# image 1/1 /content/yolov9/tiger.jpg: 480x640 1 zebra, 3735.5ms
# Speed: 2.9ms pre-process, 3735.5ms inference, 2.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
from IPython.display import Image

Image(filename= f"/content/yolov9/runs/detect/exp3/tiger.jpg", width = 1000)

# %%
# !pip install openimages
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 7.4 MB/s eta 0:00:00
# ...

# %%
from openimages.download import download_dataset

download_dataset("./data", ["Tiger"], limit=20, annotation_format= 'pascal')
# Out:
# ...
# 100%|██████████| 20/20 [00:00<00:00, 115.92it/s]
# {'tiger': {'images_dir': './data/tiger/images',
#   'annotations_dir': './data/tiger/pascal'}}

# %%
from google.colab import files
files.download('/content/data/tiger')

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="19xokjjKmAuE9QJ97fiN")
project = rf.workspace("cat-thmtr").project("bod-n3ll7")
version = project.version(1)
dataset = version.download("yolov9")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to BOD-1 in yolov9:: 100%|██████████| 7350/7350 [00:01<00:00, 3784.72it/s]

# %%
# %cd {HOME}/yolov9
# !python train.py \
--batch 16 --epochs 25 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data /content/yolov9/BOD-1/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# [Errno 2] No such file or directory: '{HOME}/yolov9'
# /content/yolov9
# 2024-06-06 12:38:04.003517: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 12:38:04.003582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-06 12:38:04.158656: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-06 12:38:04.445262: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !python detect.py --weights /content/yolov9/runs/train/exp/weights/best.pt --conf 0.9  --source /content/yolov9/BOD-1/valid/images --device 0
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/BOD-1/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.9, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25417899 parameters, 0 gradients, 102.5 GFLOPs
# image 1/307 /content/yolov9/BOD-1/valid/images/000a6c3a2c4d97e7_jpg.rf.6d6be5cc6118949d27ea060f89a0523a.jpg: 640x640 (no detections), 51.7ms
# image 2/307 /content/yolov9/BOD-1/valid/images/000f0d2fe4e5fde4_jpg.rf.2b39d0c563280cf67b5cac648dbbcfac.jpg: 640x640 1 Elephant, 51.4ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp4/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
from IPython.display import Image

Image(filename= f"/content/yolov9/runs/detect/exp2/tiger1.jpg", width = 500)

# %%
from google.colab import files
files.download('/content/yolov9/runs/train/exp/weights/best.pt')

# %%
# !python detect.py --weights /content/yolov9/runs/train/exp/weights/best.pt --conf 0.9 --source /content/yolov9/cat.jpg --device cpu
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/cat.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.9, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# gelan-c summary: 467 layers, 25411731 parameters, 0 gradients, 102.5 GFLOPs
# image 1/1 /content/yolov9/cat.jpg: 448x640 4 tigers, 1532.7ms
# Speed: 2.3ms pre-process, 1532.7ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
from IPython.display import Image

Image(filename= f"/content/yolov9/runs/detect/exp3/cat.jpg", width = 500)
